# %%
import torch
import numpy as np

# %%
# Inputs
inputs = np.array([[70,40,60],[100,60,90,],[90,50,130],[80,30,40],[60,70,100]], dtype = 'float32')

# %%
#targets
targets = np.array([[58,77],[78,100],[122,130],[25,35],[113,120]],dtype='float32')

# %%
# Tensor conversion of inputs and targets
input_tensor = torch.from_numpy(inputs)
target_tensor = torch.from_numpy(targets)
print(input_tensor)
print(target_tensor)
# Out:
# tensor([[ 70.,  40.,  60.],
#         [100.,  60.,  90.],
#         [ 90.,  50., 130.],
#         [ 80.,  30.,  40.],
#         [ 60.,  70., 100.]])
# tensor([[ 58.,  77.],
#         [ 78., 100.],
#         [122., 130.],
#         [ 25.,  35.],
#         [113., 120.]])

# %%
#Initializing random weights and biases
weights = torch.randn(2,3, requires_grad = True) #randn will pick random elements with mean = 0 and std=1
biases = torch.randn(2, requires_grad = True)

# %%
print(weights)
print(biases)
# Out:
# tensor([[-0.0779, -0.1709,  1.4723],
#         [ 0.4338, -0.2397,  0.3794]], requires_grad=True)
# tensor([ 0.4299, -1.7116], requires_grad=True)

# %%
input_tensor @ weights.t() + biases # '@' is for pytorch matrix multipication
# 't' is transpose of the tensor
# Out:
# tensor([[ 76.4757,  41.8254],
#         [114.8883,  61.4252],
#         [176.2698,  74.6598],
#         [ 47.9594,  40.9728],
#         [131.0197,  45.4711]], grad_fn=<AddBackward0>)

# %%
#Linear regression
def linear_regression_model(x):
    return x @ weights.t() + biases

# %%
#predictions from the model function
prediction = linear_regression_model(input_tensor)
print(prediction)
# Out:
# tensor([[ 76.4757,  41.8254],
#         [114.8883,  61.4252],
#         [176.2698,  74.6598],
#         [ 47.9594,  40.9728],
#         [131.0197,  45.4711]], grad_fn=<AddBackward0>)

# %%
#compare with targets
print(target_tensor)
# Out:
# tensor([[ 58.,  77.],
#         [ 78., 100.],
#         [122., 130.],
#         [ 25.,  35.],
#         [113., 120.]])

# %%
# Loss Function
difference = prediction - target_tensor
print(difference)
# Out:
# tensor([[ 18.4757, -35.1746],
#         [ 36.8883, -38.5748],
#         [ 54.2698, -55.3402],
#         [ 22.9594,   5.9728],
#         [ 18.0197, -74.5289]], grad_fn=<SubBackward0>)

# %%
difference * difference
# Out:
# tensor([[ 341.3521, 1237.2491],
#         [1360.7488, 1488.0175],
#         [2945.2068, 3062.5405],
#         [ 527.1320,   35.6745],
#         [ 324.7096, 5554.5522]], grad_fn=<MulBackward0>)

# %%
# take an average
torch.sum(difference * difference)/10
# Out:
# tensor(1687.7184, grad_fn=<DivBackward0>)

# %%
# we can get the number of elements using
torch.sum(difference * difference)/ difference.numel()
# Out:
# tensor(1687.7184, grad_fn=<DivBackward0>)

# %%
# Compute the Mean Squared Error for the model
def meanSquaredError(predictionsTensor , targetsTensor):
    difference = predictionsTensor - targetsTensor
    return torch.sum(difference * difference)/ difference.numel()

# %%
# Compute the information (f the loss is low, better the model)
model_loss = meanSquaredError(predictionsTensor = prediction, targetsTensor=target_tensor)
print(model_loss)
# Out:
# tensor(1687.7184, grad_fn=<DivBackward0>)

# %%
model_loss.backward()

# %%
print('Matrix of the weights')
print(weights)
# Out:
# Matrix of the weights
# tensor([[-0.0779, -0.1709,  1.4723],
#         [ 0.4338, -0.2397,  0.3794]], requires_grad=True)

# %%
print(weights.grad)
# Out:
# tensor([[ 2556.8684,  1523.1952,  2840.7812],
#         [-3058.8459, -2305.2639, -3998.0825]])

# %%
print(biases)
print(biases.grad)
# Out:
# tensor([ 0.4299, -1.7116], requires_grad=True)
# tensor([ 30.1226, -39.5291])

# %%
 with torch.no_grad():
        weights -= weights.grad * 1e-5
        biases -= biases.grad * 1e-5 # 1e-5 means the learning rate which determines how large your steps are

# %%
print(weights)
# Out:
# tensor([[-0.1035, -0.1862,  1.4439],
#         [ 0.4644, -0.2167,  0.4194]], requires_grad=True)

# %%
print('Previous Predictions')
print(prediction)
print('Previous loss')
print(model_loss)

##new prediction
new_preds = linear_regression_model(input_tensor)
new_loss = meanSquaredError(predictionsTensor=new_preds, targetsTensor=target_tensor)
print('new Predictions')
print(new_preds)
print('new loss')
print(new_loss)
# Out:
# Previous Predictions
# tensor([[ 76.4757,  41.8254],
#         [114.8883,  61.4252],
#         [176.2698,  74.6598],
#         [ 47.9594,  40.9728],
#         [131.0197,  45.4711]], grad_fn=<AddBackward0>)
# Previous loss
# tensor(1687.7184, grad_fn=<DivBackward0>)
# new Predictions
# tensor([[ 72.3719,  47.2880],
#         [108.8605,  69.4659],
#         [169.5136,  83.7633],
#         [ 44.3203,  45.7111],
#         [125.5783,  52.9186]], grad_fn=<AddBackward0>)
# new loss
# tensor(1251.5569, grad_fn=<DivBackward0>)

# %%
weights.grad.zero_()
biases.grad.zero_()
# Out:
# tensor([0., 0.])

# %%
for i in range(2000):
    print('Epochs number ' + str(i))
    
    # Forward pass
    predictions = linear_regression_model(input_tensor)
    
    # Compute loss
    loss = torch.nn.functional.mse_loss(predictions, target_tensor)
    print("Loss " + str(loss.item()))  # Convert loss tensor to scalar using .item()
    
    # Backward pass
    loss.backward()
    
    # Update weights and biases using gradient descent
    with torch.no_grad():
        weights -= weights.grad * 1e-5
        biases -= biases.grad * 1e-5 
        
        # Manually zero the gradients after updating weights and biases
        weights.grad.zero_()
        biases.grad.zero_()
# Out:
# Epochs number 0
# Loss 1251.556884765625
# Epochs number 1
# Loss 948.6842651367188
# Epochs number 2
# Loss 738.2310180664062
# Epochs number 3
# Loss 591.82080078125
# Epochs number 4
# Loss 489.80218505859375
# Epochs number 5
# Loss 418.5564880371094
# Epochs number 6
# Loss 368.6432800292969
# Epochs number 7
# Loss 333.5203857421875
# Epochs number 8
# Loss 308.6528625488281
# Epochs number 9
# Loss 290.8978271484375
# Epochs number 10
# Loss 278.07696533203125
# Epochs number 11
# Loss 268.6802978515625
# Epochs number 12
# Loss 261.6612243652344
# Epochs number 13
# Loss 256.29461669921875
# Epochs number 14
# Loss 252.0774688720703
# Epochs number 15
# Loss 248.6613311767578
# Epochs number 16
# Loss 245.8046112060547
# Epochs number 17
# Loss 243.33999633789062
# Epochs number 18
# Loss 241.1509552001953
# Epochs number 19
# Loss 239.1573486328125
# Epochs number 20
# Loss 237.30322265625
# Epochs number 21
# Loss 235.5498046875
# Epochs number 22
# Loss 233.8701629638672
# Epochs number 23
# Loss 232.2456817626953
# Epochs number 24
# Loss 230.6634063720703
# Epochs number 25
# Loss 229.11416625976562
# Epochs number 26
# Loss 227.59188842773438
# Epochs number 27
# Loss 226.0919647216797
# Epochs number 28
# Loss 224.6115264892578
# Epochs number 29
# Loss 223.1482391357422
# Epochs number 30
# Loss 221.70040893554688
# Epochs number 31
# Loss 220.2672882080078
# Epochs number 32
# Loss 218.847900390625
# Epochs number 33
# Loss 217.441650390625
# Epochs number 34
# Loss 216.04818725585938
# Epochs number 35
# Loss 214.66714477539062
# Epochs number 36
# Loss 213.2980499267578
# Epochs number 37
# Loss 211.94091796875
# Epochs number 38
# Loss 210.5955810546875
# Epochs number 39
# Loss 209.26181030273438
# Epochs number 40
# Loss 207.9393310546875
# Epochs number 41
# Loss 206.62826538085938
# Epochs number 42
# Loss 205.3284149169922
# Epochs number 43
# Loss 204.03952026367188
# Epochs number 44
# Loss 202.7617950439453
# Epochs number 45
# Loss 201.4947052001953
# Epochs number 46
# Loss 200.23828125
# Epochs number 47
# Loss 198.9927215576172
# Epochs number 48
# Loss 197.757568359375
# Epochs number 49
# Loss 196.5328826904297
# Epochs number 50
# Loss 195.3185577392578
# Epochs number 51
# Loss 194.114501953125
# Epochs number 52
# Loss 192.92062377929688
# Epochs number 53
# Loss 191.73678588867188
# Epochs number 54
# Loss 190.56295776367188
# Epochs number 55
# Loss 189.39901733398438
# Epochs number 56
# Loss 188.244873046875
# Epochs number 57
# Loss 187.10043334960938
# Epochs number 58
# Loss 185.96566772460938
# Epochs number 59
# Loss 184.84030151367188
# Epochs number 60
# Loss 183.7245330810547
# Epochs number 61
# Loss 182.61801147460938
# Epochs number 62
# Loss 181.52088928222656
# Epochs number 63
# Loss 180.43292236328125
# Epochs number 64
# Loss 179.35397338867188
# Epochs number 65
# Loss 178.2841033935547
# Epochs number 66
# Loss 177.22317504882812
# Epochs number 67
# Loss 176.17111206054688
# Epochs number 68
# Loss 175.12786865234375
# Epochs number 69
# Loss 174.09335327148438
# Epochs number 70
# Loss 173.06741333007812
# Epochs number 71
# Loss 172.0499725341797
# Epochs number 72
# Loss 171.04112243652344
# Epochs number 73
# Loss 170.0406036376953
# Epochs number 74
# Loss 169.04833984375
# Epochs number 75
# Loss 168.06443786621094
# Epochs number 76
# Loss 167.088623046875
# Epochs number 77
# Loss 166.12088012695312
# Epochs number 78
# Loss 165.16116333007812
# Epochs number 79
# Loss 164.20950317382812
# Epochs number 80
# Loss 163.265625
# Epochs number 81
# Loss 162.32955932617188
# Epochs number 82
# Loss 161.40122985839844
# Epochs number 83
# Loss 160.48062133789062
# Epochs number 84
# Loss 159.56765747070312
# Epochs number 85
# Loss 158.6620635986328
# Epochs number 86
# Loss 157.7639617919922
# Epochs number 87
# Loss 156.87326049804688
# Epochs number 88
# Loss 155.9899444580078
# Epochs number 89
# Loss 155.1138153076172
# Epochs number 90
# Loss 154.24496459960938
# Epochs number 91
# Loss 153.38316345214844
# Epochs number 92
# Loss 152.52850341796875
# Epochs number 93
# Loss 151.68087768554688
# Epochs number 94
# Loss 150.8400421142578
# Epochs number 95
# Loss 150.0061798095703
# Epochs number 96
# Loss 149.17910766601562
# Epochs number 97
# Loss 148.35882568359375
# Epochs number 98
# Loss 147.54519653320312
# Epochs number 99
# Loss 146.73818969726562
# Epochs number 100
# Loss 145.93777465820312
# Epochs number 101
# Loss 145.14395141601562
# Epochs number 102
# Loss 144.35643005371094
# Epochs number 103
# Loss 143.575439453125
# Epochs number 104
# Loss 142.8007049560547
# Epochs number 105
# Loss 142.0322265625
# Epochs number 106
# Loss 141.27012634277344
# Epochs number 107
# Loss 140.5140838623047
# Epochs number 108
# Loss 139.76409912109375
# Epochs number 109
# Loss 139.0203857421875
# Epochs number 110
# Loss 138.2824249267578
# Epochs number 111
# Loss 137.55056762695312
# Epochs number 112
# Loss 136.82449340820312
# Epochs number 113
# Loss 136.10440063476562
# Epochs number 114
# Loss 135.38998413085938
# Epochs number 115
# Loss 134.68142700195312
# Epochs number 116
# Loss 133.97854614257812
# Epochs number 117
# Loss 133.28125
# Epochs number 118
# Loss 132.58953857421875
# Epochs number 119
# Loss 131.90335083007812
# Epochs number 120
# Loss 131.22268676757812
# Epochs number 121
# Loss 130.54745483398438
# Epochs number 122
# Loss 129.877685546875
# Epochs number 123
# Loss 129.213134765625
# Epochs number 124
# Loss 128.55397033691406
# Epochs number 125
# Loss 127.89997863769531
# Epochs number 126
# Loss 127.25128173828125
# Epochs number 127
# Loss 126.6076889038086
# Epochs number 128
# Loss 125.96917724609375
# Epochs number 129
# Loss 125.33575439453125
# Epochs number 130
# Loss 124.70738220214844
# Epochs number 131
# Loss 124.0839614868164
# Epochs number 132
# Loss 123.46551513671875
# Epochs number 133
# Loss 122.85186767578125
# Epochs number 134
# Loss 122.24310302734375
# Epochs number 135
# Loss 121.63911437988281
# Epochs number 136
# Loss 121.0399169921875
# Epochs number 137
# Loss 120.44548034667969
# Epochs number 138
# Loss 119.85563659667969
# Epochs number 139
# Loss 119.2703857421875
# Epochs number 140
# Loss 118.68983459472656
# Epochs number 141
# Loss 118.1137924194336
# Epochs number 142
# Loss 117.54225158691406
# Epochs number 143
# Loss 116.9752426147461
# Epochs number 144
# Loss 116.4126205444336
# Epochs number 145
# Loss 115.85429382324219
# Epochs number 146
# Loss 115.30043029785156
# Epochs number 147
# Loss 114.7508316040039
# Epochs number 148
# Loss 114.20550537109375
# Epochs number 149
# Loss 113.66439056396484
# Epochs number 150
# Loss 113.1275405883789
# Epochs number 151
# Loss 112.5948257446289
# Epochs number 152
# Loss 112.06620788574219
# Epochs number 153
# Loss 111.54170227050781
# Epochs number 154
# Loss 111.02132415771484
# Epochs number 155
# Loss 110.50484466552734
# Epochs number 156
# Loss 109.99238586425781
# Epochs number 157
# Loss 109.4838638305664
# Epochs number 158
# Loss 108.97929382324219
# Epochs number 159
# Loss 108.47853088378906
# Epochs number 160
# Loss 107.9817123413086
# Epochs number 161
# Loss 107.4886474609375
# Epochs number 162
# Loss 106.9993667602539
# Epochs number 163
# Loss 106.51385498046875
# Epochs number 164
# Loss 106.031982421875
# Epochs number 165
# Loss 105.55381774902344
# Epochs number 166
# Loss 105.07926177978516
# Epochs number 167
# Loss 104.6083984375
# Epochs number 168
# Loss 104.14103698730469
# Epochs number 169
# Loss 103.6772689819336
# Epochs number 170
# Loss 103.21707916259766
# Epochs number 171
# Loss 102.76023864746094
# Epochs number 172
# Loss 102.30696105957031
# Epochs number 173
# Loss 101.85707092285156
# Epochs number 174
# Loss 101.41062927246094
# Epochs number 175
# Loss 100.96734619140625
# Epochs number 176
# Loss 100.52764892578125
# Epochs number 177
# Loss 100.09114837646484
# Epochs number 178
# Loss 99.65797424316406
# Epochs number 179
# Loss 99.22798156738281
# Epochs number 180
# Loss 98.80125427246094
# Epochs number 181
# Loss 98.37773132324219
# Epochs number 182
# Loss 97.95735931396484
# Epochs number 183
# Loss 97.54013061523438
# Epochs number 184
# Loss 97.12599182128906
# Epochs number 185
# Loss 96.71498107910156
# Epochs number 186
# Loss 96.30693054199219
# Epochs number 187
# Loss 95.9019775390625
# Epochs number 188
# Loss 95.50008392333984
# Epochs number 189
# Loss 95.10105895996094
# Epochs number 190
# Loss 94.7050552368164
# Epochs number 191
# Loss 94.31199645996094
# Epochs number 192
# Loss 93.92167663574219
# Epochs number 193
# Loss 93.53446960449219
# Epochs number 194
# Loss 93.15003967285156
# Epochs number 195
# Loss 92.76832580566406
# Epochs number 196
# Loss 92.38946533203125
# Epochs number 197
# Loss 92.0134048461914
# Epochs number 198
# Loss 91.64012908935547
# Epochs number 199
# Loss 91.26953125
# Epochs number 200
# Loss 90.90162658691406
# Epochs number 201
# Loss 90.53639221191406
# Epochs number 202
# Loss 90.17384338378906
# Epochs number 203
# Loss 89.8139419555664
# Epochs number 204
# Loss 89.4566650390625
# Epochs number 205
# Loss 89.10194396972656
# Epochs number 206
# Loss 88.74980926513672
# Epochs number 207
# Loss 88.4002456665039
# Epochs number 208
# Loss 88.05316162109375
# Epochs number 209
# Loss 87.70857238769531
# Epochs number 210
# Loss 87.36650085449219
# Epochs number 211
# Loss 87.02693176269531
# Epochs number 212
# Loss 86.68974304199219
# Epochs number 213
# Loss 86.35489654541016
# Epochs number 214
# Loss 86.02252197265625
# Epochs number 215
# Loss 85.6925277709961
# Epochs number 216
# Loss 85.36487579345703
# Epochs number 217
# Loss 85.0395736694336
# Epochs number 218
# Loss 84.71656799316406
# Epochs number 219
# Loss 84.3958511352539
# Epochs number 220
# Loss 84.07747650146484
# Epochs number 221
# Loss 83.76130676269531
# Epochs number 222
# Loss 83.44742584228516
# Epochs number 223
# Loss 83.13563537597656
# Epochs number 224
# Loss 82.82614135742188
# Epochs number 225
# Loss 82.51876831054688
# Epochs number 226
# Loss 82.2136001586914
# Epochs number 227
# Loss 81.91059112548828
# Epochs number 228
# Loss 81.6095962524414
# Epochs number 229
# Loss 81.31082916259766
# Epochs number 230
# Loss 81.01409912109375
# Epochs number 231
# Loss 80.71946716308594
# Epochs number 232
# Loss 80.4268798828125
# Epochs number 233
# Loss 80.13626861572266
# Epochs number 234
# Loss 79.84780883789062
# Epochs number 235
# Loss 79.56123352050781
# Epochs number 236
# Loss 79.2766342163086
# Epochs number 237
# Loss 78.99412536621094
# Epochs number 238
# Loss 78.71342468261719
# Epochs number 239
# Loss 78.43473815917969
# Epochs number 240
# Loss 78.15797424316406
# Epochs number 241
# Loss 77.88302612304688
# Epochs number 242
# Loss 77.61003875732422
# Epochs number 243
# Loss 77.33892822265625
# Epochs number 244
# Loss 77.06966400146484
# Epochs number 245
# Loss 76.80220031738281
# Epochs number 246
# Loss 76.53655242919922
# Epochs number 247
# Loss 76.2727279663086
# Epochs number 248
# Loss 76.0107192993164
# Epochs number 249
# Loss 75.75048828125
# Epochs number 250
# Loss 75.49199676513672
# Epochs number 251
# Loss 75.23529052734375
# Epochs number 252
# Loss 74.98027801513672
# Epochs number 253
# Loss 74.72697448730469
# Epochs number 254
# Loss 74.47541809082031
# Epochs number 255
# Loss 74.22554016113281
# Epochs number 256
# Loss 73.9773178100586
# Epochs number 257
# Loss 73.73075103759766
# Epochs number 258
# Loss 73.48585510253906
# Epochs number 259
# Loss 73.24256896972656
# Epochs number 260
# Loss 73.00088500976562
# Epochs number 261
# Loss 72.76081848144531
# Epochs number 262
# Loss 72.52238464355469
# Epochs number 263
# Loss 72.2854995727539
# Epochs number 264
# Loss 72.05020904541016
# Epochs number 265
# Loss 71.81641387939453
# Epochs number 266
# Loss 71.58425903320312
# Epochs number 267
# Loss 71.35350036621094
# Epochs number 268
# Loss 71.12430572509766
# Epochs number 269
# Loss 70.89664459228516
# Epochs number 270
# Loss 70.67045593261719
# Epochs number 271
# Loss 70.44575500488281
# Epochs number 272
# Loss 70.22251892089844
# Epochs number 273
# Loss 70.00071716308594
# Epochs number 274
# Loss 69.78034973144531
# Epochs number 275
# Loss 69.56143188476562
# Epochs number 276
# Loss 69.34393310546875
# Epochs number 277
# Loss 69.12786865234375
# Epochs number 278
# Loss 68.91315460205078
# Epochs number 279
# Loss 68.69979095458984
# Epochs number 280
# Loss 68.48786163330078
# Epochs number 281
# Loss 68.27729797363281
# Epochs number 282
# Loss 68.06800842285156
# Epochs number 283
# Loss 67.86013793945312
# Epochs number 284
# Loss 67.65353393554688
# Epochs number 285
# Loss 67.44828033447266
# Epochs number 286
# Loss 67.24432373046875
# Epochs number 287
# Loss 67.04169464111328
# Epochs number 288
# Loss 66.84028625488281
# Epochs number 289
# Loss 66.64019012451172
# Epochs number 290
# Loss 66.44132995605469
# Epochs number 291
# Loss 66.24374389648438
# Epochs number 292
# Loss 66.04739379882812
# Epochs number 293
# Loss 65.85225677490234
# Epochs number 294
# Loss 65.65835571289062
# Epochs number 295
# Loss 65.46571350097656
# Epochs number 296
# Loss 65.27420806884766
# Epochs number 297
# Loss 65.08394622802734
# Epochs number 298
# Loss 64.89482116699219
# Epochs number 299
# Loss 64.70689392089844
# Epochs number 300
# Loss 64.52008056640625
# Epochs number 301
# Loss 64.33448791503906
# Epochs number 302
# Loss 64.14998626708984
# Epochs number 303
# Loss 63.966712951660156
# Epochs number 304
# Loss 63.78448486328125
# Epochs number 305
# Loss 63.603431701660156
# Epochs number 306
# Loss 63.423439025878906
# Epochs number 307
# Loss 63.244544982910156
# Epochs number 308
# Loss 63.066734313964844
# Epochs number 309
# Loss 62.89005661010742
# Epochs number 310
# Loss 62.71442413330078
# Epochs number 311
# Loss 62.53986358642578
# Epochs number 312
# Loss 62.36627960205078
# Epochs number 313
# Loss 62.193885803222656
# Epochs number 314
# Loss 62.02241134643555
# Epochs number 315
# Loss 61.85204315185547
# Epochs number 316
# Loss 61.68267059326172
# Epochs number 317
# Loss 61.51428985595703
# Epochs number 318
# Loss 61.346923828125
# Epochs number 319
# Loss 61.18062210083008
# Epochs number 320
# Loss 61.01518630981445
# Epochs number 321
# Loss 60.850860595703125
# Epochs number 322
# Loss 60.68745040893555
# Epochs number 323
# Loss 60.52501678466797
# Epochs number 324
# Loss 60.363502502441406
# Epochs number 325
# Loss 60.203041076660156
# Epochs number 326
# Loss 60.04340744018555
# Epochs number 327
# Loss 59.88480758666992
# Epochs number 328
# Loss 59.72710037231445
# Epochs number 329
# Loss 59.570289611816406
# Epochs number 330
# Loss 59.414405822753906
# Epochs number 331
# Loss 59.25944900512695
# Epochs number 332
# Loss 59.10538864135742
# Epochs number 333
# Loss 58.952186584472656
# Epochs number 334
# Loss 58.79994583129883
# Epochs number 335
# Loss 58.648536682128906
# Epochs number 336
# Loss 58.49798583984375
# Epochs number 337
# Loss 58.348365783691406
# Epochs number 338
# Loss 58.19951248168945
# Epochs number 339
# Loss 58.05157470703125
# Epochs number 340
# Loss 57.904441833496094
# Epochs number 341
# Loss 57.75822067260742
# Epochs number 342
# Loss 57.61275100708008
# Epochs number 343
# Loss 57.468162536621094
# Epochs number 344
# Loss 57.32439041137695
# Epochs number 345
# Loss 57.181427001953125
# Epochs number 346
# Loss 57.03919219970703
# Epochs number 347
# Loss 56.897926330566406
# Epochs number 348
# Loss 56.7573127746582
# Epochs number 349
# Loss 56.617523193359375
# Epochs number 350
# Loss 56.478553771972656
# Epochs number 351
# Loss 56.3403434753418
# Epochs number 352
# Loss 56.20283126831055
# Epochs number 353
# Loss 56.066184997558594
# Epochs number 354
# Loss 55.9301872253418
# Epochs number 355
# Loss 55.7950553894043
# Epochs number 356
# Loss 55.66064453125
# Epochs number 357
# Loss 55.526939392089844
# Epochs number 358
# Loss 55.39398956298828
# Epochs number 359
# Loss 55.26176071166992
# Epochs number 360
# Loss 55.130287170410156
# Epochs number 361
# Loss 54.999534606933594
# Epochs number 362
# Loss 54.86940383911133
# Epochs number 363
# Loss 54.7401237487793
# Epochs number 364
# Loss 54.611473083496094
# Epochs number 365
# Loss 54.4835205078125
# Epochs number 366
# Loss 54.3562126159668
# Epochs number 367
# Loss 54.22965621948242
# Epochs number 368
# Loss 54.10376739501953
# Epochs number 369
# Loss 53.97858810424805
# Epochs number 370
# Loss 53.85405731201172
# Epochs number 371
# Loss 53.730201721191406
# Epochs number 372
# Loss 53.606956481933594
# Epochs number 373
# Loss 53.484405517578125
# Epochs number 374
# Loss 53.36248779296875
# Epochs number 375
# Loss 53.24125289916992
# Epochs number 376
# Loss 53.120628356933594
# Epochs number 377
# Loss 53.000694274902344
# Epochs number 378
# Loss 52.88129806518555
# Epochs number 379
# Loss 52.76259231567383
# Epochs number 380
# Loss 52.644500732421875
# Epochs number 381
# Loss 52.52705001831055
# Epochs number 382
# Loss 52.41014862060547
# Epochs number 383
# Loss 52.29393768310547
# Epochs number 384
# Loss 52.178260803222656
# Epochs number 385
# Loss 52.063255310058594
# Epochs number 386
# Loss 51.94881057739258
# Epochs number 387
# Loss 51.83498001098633
# Epochs number 388
# Loss 51.721702575683594
# Epochs number 389
# Loss 51.60900115966797
# Epochs number 390
# Loss 51.49689865112305
# Epochs number 391
# Loss 51.3853759765625
# Epochs number 392
# Loss 51.27440643310547
# Epochs number 393
# Loss 51.1640510559082
# Epochs number 394
# Loss 51.05419921875
# Epochs number 395
# Loss 50.94487380981445
# Epochs number 396
# Loss 50.83620071411133
# Epochs number 397
# Loss 50.728023529052734
# Epochs number 398
# Loss 50.62041091918945
# Epochs number 399
# Loss 50.513343811035156
# Epochs number 400
# Loss 50.406761169433594
# Epochs number 401
# Loss 50.30077362060547
# Epochs number 402
# Loss 50.19530487060547
# Epochs number 403
# Loss 50.09033966064453
# Epochs number 404
# Loss 49.985939025878906
# Epochs number 405
# Loss 49.88201141357422
# Epochs number 406
# Loss 49.77858352661133
# Epochs number 407
# Loss 49.67572784423828
# Epochs number 408
# Loss 49.573387145996094
# Epochs number 409
# Loss 49.471519470214844
# Epochs number 410
# Loss 49.37012481689453
# Epochs number 411
# Loss 49.26925277709961
# Epochs number 412
# Loss 49.16889190673828
# Epochs number 413
# Loss 49.06902313232422
# Epochs number 414
# Loss 48.96959686279297
# Epochs number 415
# Loss 48.870643615722656
# Epochs number 416
# Loss 48.77226257324219
# Epochs number 417
# Loss 48.67428970336914
# Epochs number 418
# Loss 48.57683563232422
# Epochs number 419
# Loss 48.47978973388672
# Epochs number 420
# Loss 48.38322830200195
# Epochs number 421
# Loss 48.28715896606445
# Epochs number 422
# Loss 48.191532135009766
# Epochs number 423
# Loss 48.09632873535156
# Epochs number 424
# Loss 48.00162124633789
# Epochs number 425
# Loss 47.90736389160156
# Epochs number 426
# Loss 47.81354522705078
# Epochs number 427
# Loss 47.72020721435547
# Epochs number 428
# Loss 47.627174377441406
# Epochs number 429
# Loss 47.534759521484375
# Epochs number 430
# Loss 47.442657470703125
# Epochs number 431
# Loss 47.351070404052734
# Epochs number 432
# Loss 47.25983428955078
# Epochs number 433
# Loss 47.169097900390625
# Epochs number 434
# Loss 47.07875061035156
# Epochs number 435
# Loss 46.98884582519531
# Epochs number 436
# Loss 46.89928436279297
# Epochs number 437
# Loss 46.81018829345703
# Epochs number 438
# Loss 46.721492767333984
# Epochs number 439
# Loss 46.63323211669922
# Epochs number 440
# Loss 46.54534149169922
# Epochs number 441
# Loss 46.45790481567383
# Epochs number 442
# Loss 46.37085723876953
# Epochs number 443
# Loss 46.28412628173828
# Epochs number 444
# Loss 46.1978874206543
# Epochs number 445
# Loss 46.11201095581055
# Epochs number 446
# Loss 46.026512145996094
# Epochs number 447
# Loss 45.941383361816406
# Epochs number 448
# Loss 45.856658935546875
# Epochs number 449
# Loss 45.77237319946289
# Epochs number 450
# Loss 45.688438415527344
# Epochs number 451
# Loss 45.60479736328125
# Epochs number 452
# Loss 45.52162551879883
# Epochs number 453
# Loss 45.438819885253906
# Epochs number 454
# Loss 45.3563232421875
# Epochs number 455
# Loss 45.274200439453125
# Epochs number 456
# Loss 45.19252395629883
# Epochs number 457
# Loss 45.11111068725586
# Epochs number 458
# Loss 45.03012466430664
# Epochs number 459
# Loss 44.949485778808594
# Epochs number 460
# Loss 44.86917495727539
# Epochs number 461
# Loss 44.78921890258789
# Epochs number 462
# Loss 44.70960998535156
# Epochs number 463
# Loss 44.63036346435547
# Epochs number 464
# Loss 44.55147171020508
# Epochs number 465
# Loss 44.47294235229492
# Epochs number 466
# Loss 44.394710540771484
# Epochs number 467
# Loss 44.31685256958008
# Epochs number 468
# Loss 44.23929214477539
# Epochs number 469
# Loss 44.16211700439453
# Epochs number 470
# Loss 44.085243225097656
# Epochs number 471
# Loss 44.00867462158203
# Epochs number 472
# Loss 43.93248748779297
# Epochs number 473
# Loss 43.856571197509766
# Epochs number 474
# Loss 43.781002044677734
# Epochs number 475
# Loss 43.70577621459961
# Epochs number 476
# Loss 43.63090896606445
# Epochs number 477
# Loss 43.5562744140625
# Epochs number 478
# Loss 43.482025146484375
# Epochs number 479
# Loss 43.407997131347656
# Epochs number 480
# Loss 43.33434295654297
# Epochs number 481
# Loss 43.261009216308594
# Epochs number 482
# Loss 43.18800354003906
# Epochs number 483
# Loss 43.11522674560547
# Epochs number 484
# Loss 43.04278564453125
# Epochs number 485
# Loss 42.9706916809082
# Epochs number 486
# Loss 42.898841857910156
# Epochs number 487
# Loss 42.82734680175781
# Epochs number 488
# Loss 42.75608444213867
# Epochs number 489
# Loss 42.68513488769531
# Epochs number 490
# Loss 42.6145133972168
# Epochs number 491
# Loss 42.544151306152344
# Epochs number 492
# Loss 42.47406768798828
# Epochs number 493
# Loss 42.40431594848633
# Epochs number 494
# Loss 42.33485794067383
# Epochs number 495
# Loss 42.265625
# Epochs number 496
# Loss 42.19670486450195
# Epochs number 497
# Loss 42.12805938720703
# Epochs number 498
# Loss 42.05967330932617
# Epochs number 499
# Loss 41.991600036621094
# Epochs number 500
# Loss 41.92378616333008
# Epochs number 501
# Loss 41.856224060058594
# Epochs number 502
# Loss 41.78900909423828
# Epochs number 503
# Loss 41.72199249267578
# Epochs number 504
# Loss 41.6552619934082
# Epochs number 505
# Loss 41.588802337646484
# Epochs number 506
# Loss 41.52266311645508
# Epochs number 507
# Loss 41.45664596557617
# Epochs number 508
# Loss 41.391029357910156
# Epochs number 509
# Loss 41.32558822631836
# Epochs number 510
# Loss 41.26042938232422
# Epochs number 511
# Loss 41.195594787597656
# Epochs number 512
# Loss 41.13094711303711
# Epochs number 513
# Loss 41.06654357910156
# Epochs number 514
# Loss 41.00242614746094
# Epochs number 515
# Loss 40.938568115234375
# Epochs number 516
# Loss 40.87495422363281
# Epochs number 517
# Loss 40.811607360839844
# Epochs number 518
# Loss 40.74840545654297
# Epochs number 519
# Loss 40.685508728027344
# Epochs number 520
# Loss 40.622894287109375
# Epochs number 521
# Loss 40.56049346923828
# Epochs number 522
# Loss 40.49838638305664
# Epochs number 523
# Loss 40.436424255371094
# Epochs number 524
# Loss 40.37477493286133
# Epochs number 525
# Loss 40.31332778930664
# Epochs number 526
# Loss 40.25212478637695
# Epochs number 527
# Loss 40.1911506652832
# Epochs number 528
# Loss 40.13039016723633
# Epochs number 529
# Loss 40.06989669799805
# Epochs number 530
# Loss 40.009613037109375
# Epochs number 531
# Loss 39.94955825805664
# Epochs number 532
# Loss 39.88976287841797
# Epochs number 533
# Loss 39.83024215698242
# Epochs number 534
# Loss 39.77083206176758
# Epochs number 535
# Loss 39.711700439453125
# Epochs number 536
# Loss 39.65275192260742
# Epochs number 537
# Loss 39.594032287597656
# Epochs number 538
# Loss 39.535579681396484
# Epochs number 539
# Loss 39.47733688354492
# Epochs number 540
# Loss 39.4193000793457
# Epochs number 541
# Loss 39.36146926879883
# Epochs number 542
# Loss 39.3038215637207
# Epochs number 543
# Loss 39.246482849121094
# Epochs number 544
# Loss 39.189292907714844
# Epochs number 545
# Loss 39.1323356628418
# Epochs number 546
# Loss 39.075523376464844
# Epochs number 547
# Loss 39.01898956298828
# Epochs number 548
# Loss 38.96271514892578
# Epochs number 549
# Loss 38.906524658203125
# Epochs number 550
# Loss 38.8505859375
# Epochs number 551
# Loss 38.7949104309082
# Epochs number 552
# Loss 38.73932647705078
# Epochs number 553
# Loss 38.684059143066406
# Epochs number 554
# Loss 38.62889862060547
# Epochs number 555
# Loss 38.57398986816406
# Epochs number 556
# Loss 38.51927947998047
# Epochs number 557
# Loss 38.4647331237793
# Epochs number 558
# Loss 38.410465240478516
# Epochs number 559
# Loss 38.356292724609375
# Epochs number 560
# Loss 38.302391052246094
# Epochs number 561
# Loss 38.24863815307617
# Epochs number 562
# Loss 38.195091247558594
# Epochs number 563
# Loss 38.141780853271484
# Epochs number 564
# Loss 38.08858108520508
# Epochs number 565
# Loss 38.03565979003906
# Epochs number 566
# Loss 37.98279571533203
# Epochs number 567
# Loss 37.930240631103516
# Epochs number 568
# Loss 37.877830505371094
# Epochs number 569
# Loss 37.82561111450195
# Epochs number 570
# Loss 37.77358627319336
# Epochs number 571
# Loss 37.72167205810547
# Epochs number 572
# Loss 37.6700439453125
# Epochs number 573
# Loss 37.618526458740234
# Epochs number 574
# Loss 37.567237854003906
# Epochs number 575
# Loss 37.516109466552734
# Epochs number 576
# Loss 37.46512985229492
# Epochs number 577
# Loss 37.41438674926758
# Epochs number 578
# Loss 37.3637809753418
# Epochs number 579
# Loss 37.313377380371094
# Epochs number 580
# Loss 37.26309585571289
# Epochs number 581
# Loss 37.213035583496094
# Epochs number 582
# Loss 37.16316223144531
# Epochs number 583
# Loss 37.113433837890625
# Epochs number 584
# Loss 37.063865661621094
# Epochs number 585
# Loss 37.01449203491211
# Epochs number 586
# Loss 36.965274810791016
# Epochs number 587
# Loss 36.91625213623047
# Epochs number 588
# Loss 36.86735534667969
# Epochs number 589
# Loss 36.81868362426758
# Epochs number 590
# Loss 36.77011489868164
# Epochs number 591
# Loss 36.72175216674805
# Epochs number 592
# Loss 36.673545837402344
# Epochs number 593
# Loss 36.625492095947266
# Epochs number 594
# Loss 36.57759475708008
# Epochs number 595
# Loss 36.52986145019531
# Epochs number 596
# Loss 36.482337951660156
# Epochs number 597
# Loss 36.4349365234375
# Epochs number 598
# Loss 36.3877067565918
# Epochs number 599
# Loss 36.340641021728516
# Epochs number 600
# Loss 36.29370880126953
# Epochs number 601
# Loss 36.246986389160156
# Epochs number 602
# Loss 36.20033645629883
# Epochs number 603
# Loss 36.15386962890625
# Epochs number 604
# Loss 36.107582092285156
# Epochs number 605
# Loss 36.06145477294922
# Epochs number 606
# Loss 36.015438079833984
# Epochs number 607
# Loss 35.96965789794922
# Epochs number 608
# Loss 35.92395782470703
# Epochs number 609
# Loss 35.87841033935547
# Epochs number 610
# Loss 35.833072662353516
# Epochs number 611
# Loss 35.78783416748047
# Epochs number 612
# Loss 35.74277114868164
# Epochs number 613
# Loss 35.69780349731445
# Epochs number 614
# Loss 35.653045654296875
# Epochs number 615
# Loss 35.60840606689453
# Epochs number 616
# Loss 35.56391143798828
# Epochs number 617
# Loss 35.51959991455078
# Epochs number 618
# Loss 35.47539520263672
# Epochs number 619
# Loss 35.43132400512695
# Epochs number 620
# Loss 35.387428283691406
# Epochs number 621
# Loss 35.343658447265625
# Epochs number 622
# Loss 35.29998779296875
# Epochs number 623
# Loss 35.256561279296875
# Epochs number 624
# Loss 35.213199615478516
# Epochs number 625
# Loss 35.17001724243164
# Epochs number 626
# Loss 35.126949310302734
# Epochs number 627
# Loss 35.084041595458984
# Epochs number 628
# Loss 35.041263580322266
# Epochs number 629
# Loss 34.99859619140625
# Epochs number 630
# Loss 34.95610427856445
# Epochs number 631
# Loss 34.913719177246094
# Epochs number 632
# Loss 34.871498107910156
# Epochs number 633
# Loss 34.82938003540039
# Epochs number 634
# Loss 34.78744888305664
# Epochs number 635
# Loss 34.74557876586914
# Epochs number 636
# Loss 34.703887939453125
# Epochs number 637
# Loss 34.66233444213867
# Epochs number 638
# Loss 34.62088394165039
# Epochs number 639
# Loss 34.57963562011719
# Epochs number 640
# Loss 34.538414001464844
# Epochs number 641
# Loss 34.49742126464844
# Epochs number 642
# Loss 34.45647430419922
# Epochs number 643
# Loss 34.415706634521484
# Epochs number 644
# Loss 34.375038146972656
# Epochs number 645
# Loss 34.33452224731445
# Epochs number 646
# Loss 34.29414749145508
# Epochs number 647
# Loss 34.25388717651367
# Epochs number 648
# Loss 34.213706970214844
# Epochs number 649
# Loss 34.173683166503906
# Epochs number 650
# Loss 34.13382339477539
# Epochs number 651
# Loss 34.09406280517578
# Epochs number 652
# Loss 34.05441665649414
# Epochs number 653
# Loss 34.01488494873047
# Epochs number 654
# Loss 33.97552490234375
# Epochs number 655
# Loss 33.936222076416016
# Epochs number 656
# Loss 33.8970832824707
# Epochs number 657
# Loss 33.85803985595703
# Epochs number 658
# Loss 33.81914520263672
# Epochs number 659
# Loss 33.780357360839844
# Epochs number 660
# Loss 33.74169921875
# Epochs number 661
# Loss 33.7031135559082
# Epochs number 662
# Loss 33.664710998535156
# Epochs number 663
# Loss 33.62642288208008
# Epochs number 664
# Loss 33.58821487426758
# Epochs number 665
# Loss 33.550148010253906
# Epochs number 666
# Loss 33.512142181396484
# Epochs number 667
# Loss 33.47431564331055
# Epochs number 668
# Loss 33.436614990234375
# Epochs number 669
# Loss 33.39897155761719
# Epochs number 670
# Loss 33.36149978637695
# Epochs number 671
# Loss 33.32411575317383
# Epochs number 672
# Loss 33.286842346191406
# Epochs number 673
# Loss 33.249671936035156
# Epochs number 674
# Loss 33.212615966796875
# Epochs number 675
# Loss 33.17572021484375
# Epochs number 676
# Loss 33.1389045715332
# Epochs number 677
# Loss 33.10221481323242
# Epochs number 678
# Loss 33.065574645996094
# Epochs number 679
# Loss 33.02912902832031
# Epochs number 680
# Loss 32.992774963378906
# Epochs number 681
# Loss 32.956478118896484
# Epochs number 682
# Loss 32.92033767700195
# Epochs number 683
# Loss 32.88425827026367
# Epochs number 684
# Loss 32.848358154296875
# Epochs number 685
# Loss 32.812522888183594
# Epochs number 686
# Loss 32.77680206298828
# Epochs number 687
# Loss 32.74117660522461
# Epochs number 688
# Loss 32.705665588378906
# Epochs number 689
# Loss 32.67023849487305
# Epochs number 690
# Loss 32.63495635986328
# Epochs number 691
# Loss 32.599754333496094
# Epochs number 692
# Loss 32.564701080322266
# Epochs number 693
# Loss 32.529701232910156
# Epochs number 694
# Loss 32.494834899902344
# Epochs number 695
# Loss 32.460052490234375
# Epochs number 696
# Loss 32.425376892089844
# Epochs number 697
# Loss 32.390830993652344
# Epochs number 698
# Loss 32.356346130371094
# Epochs number 699
# Loss 32.32197952270508
# Epochs number 700
# Loss 32.28768539428711
# Epochs number 701
# Loss 32.25355529785156
# Epochs number 702
# Loss 32.21947479248047
# Epochs number 703
# Loss 32.18556594848633
# Epochs number 704
# Loss 32.15167999267578
# Epochs number 705
# Loss 32.11792755126953
# Epochs number 706
# Loss 32.084228515625
# Epochs number 707
# Loss 32.05068588256836
# Epochs number 708
# Loss 32.01720428466797
# Epochs number 709
# Loss 31.983871459960938
# Epochs number 710
# Loss 31.950557708740234
# Epochs number 711
# Loss 31.917394638061523
# Epochs number 712
# Loss 31.88431739807129
# Epochs number 713
# Loss 31.851348876953125
# Epochs number 714
# Loss 31.81845474243164
# Epochs number 715
# Loss 31.785663604736328
# Epochs number 716
# Loss 31.752975463867188
# Epochs number 717
# Loss 31.72042465209961
# Epochs number 718
# Loss 31.68789291381836
# Epochs number 719
# Loss 31.655460357666016
# Epochs number 720
# Loss 31.623144149780273
# Epochs number 721
# Loss 31.590927124023438
# Epochs number 722
# Loss 31.558818817138672
# Epochs number 723
# Loss 31.526775360107422
# Epochs number 724
# Loss 31.494836807250977
# Epochs number 725
# Loss 31.462970733642578
# Epochs number 726
# Loss 31.43124771118164
# Epochs number 727
# Loss 31.399560928344727
# Epochs number 728
# Loss 31.36798667907715
# Epochs number 729
# Loss 31.336498260498047
# Epochs number 730
# Loss 31.30511474609375
# Epochs number 731
# Loss 31.273788452148438
# Epochs number 732
# Loss 31.242578506469727
# Epochs number 733
# Loss 31.21145248413086
# Epochs number 734
# Loss 31.1804256439209
# Epochs number 735
# Loss 31.14950180053711
# Epochs number 736
# Loss 31.11861801147461
# Epochs number 737
# Loss 31.087841033935547
# Epochs number 738
# Loss 31.057165145874023
# Epochs number 739
# Loss 31.02658462524414
# Epochs number 740
# Loss 30.996051788330078
# Epochs number 741
# Loss 30.965618133544922
# Epochs number 742
# Loss 30.935314178466797
# Epochs number 743
# Loss 30.905038833618164
# Epochs number 744
# Loss 30.874902725219727
# Epochs number 745
# Loss 30.844802856445312
# Epochs number 746
# Loss 30.814849853515625
# Epochs number 747
# Loss 30.7849063873291
# Epochs number 748
# Loss 30.755102157592773
# Epochs number 749
# Loss 30.725322723388672
# Epochs number 750
# Loss 30.695690155029297
# Epochs number 751
# Loss 30.666118621826172
# Epochs number 752
# Loss 30.636621475219727
# Epochs number 753
# Loss 30.607213973999023
# Epochs number 754
# Loss 30.5778865814209
# Epochs number 755
# Loss 30.548669815063477
# Epochs number 756
# Loss 30.519512176513672
# Epochs number 757
# Loss 30.49045181274414
# Epochs number 758
# Loss 30.461414337158203
# Epochs number 759
# Loss 30.432531356811523
# Epochs number 760
# Loss 30.403705596923828
# Epochs number 761
# Loss 30.374950408935547
# Epochs number 762
# Loss 30.346242904663086
# Epochs number 763
# Loss 30.317678451538086
# Epochs number 764
# Loss 30.289154052734375
# Epochs number 765
# Loss 30.260726928710938
# Epochs number 766
# Loss 30.23236083984375
# Epochs number 767
# Loss 30.204111099243164
# Epochs number 768
# Loss 30.17592430114746
# Epochs number 769
# Loss 30.14778709411621
# Epochs number 770
# Loss 30.119735717773438
# Epochs number 771
# Loss 30.0918025970459
# Epochs number 772
# Loss 30.063922882080078
# Epochs number 773
# Loss 30.03611183166504
# Epochs number 774
# Loss 30.008358001708984
# Epochs number 775
# Loss 29.98075294494629
# Epochs number 776
# Loss 29.953136444091797
# Epochs number 777
# Loss 29.9256534576416
# Epochs number 778
# Loss 29.898204803466797
# Epochs number 779
# Loss 29.870895385742188
# Epochs number 780
# Loss 29.843612670898438
# Epochs number 781
# Loss 29.816421508789062
# Epochs number 782
# Loss 29.789264678955078
# Epochs number 783
# Loss 29.762243270874023
# Epochs number 784
# Loss 29.735286712646484
# Epochs number 785
# Loss 29.7083740234375
# Epochs number 786
# Loss 29.681564331054688
# Epochs number 787
# Loss 29.65478515625
# Epochs number 788
# Loss 29.628149032592773
# Epochs number 789
# Loss 29.601531982421875
# Epochs number 790
# Loss 29.574987411499023
# Epochs number 791
# Loss 29.548542022705078
# Epochs number 792
# Loss 29.52217674255371
# Epochs number 793
# Loss 29.49582862854004
# Epochs number 794
# Loss 29.469614028930664
# Epochs number 795
# Loss 29.443424224853516
# Epochs number 796
# Loss 29.417346954345703
# Epochs number 797
# Loss 29.391326904296875
# Epochs number 798
# Loss 29.365375518798828
# Epochs number 799
# Loss 29.3394775390625
# Epochs number 800
# Loss 29.31368064880371
# Epochs number 801
# Loss 29.287912368774414
# Epochs number 802
# Loss 29.262258529663086
# Epochs number 803
# Loss 29.236623764038086
# Epochs number 804
# Loss 29.21111488342285
# Epochs number 805
# Loss 29.185638427734375
# Epochs number 806
# Loss 29.16025733947754
# Epochs number 807
# Loss 29.134929656982422
# Epochs number 808
# Loss 29.10967445373535
# Epochs number 809
# Loss 29.0844669342041
# Epochs number 810
# Loss 29.059356689453125
# Epochs number 811
# Loss 29.034305572509766
# Epochs number 812
# Loss 29.009307861328125
# Epochs number 813
# Loss 28.984405517578125
# Epochs number 814
# Loss 28.95957374572754
# Epochs number 815
# Loss 28.934743881225586
# Epochs number 816
# Loss 28.91005516052246
# Epochs number 817
# Loss 28.885412216186523
# Epochs number 818
# Loss 28.860836029052734
# Epochs number 819
# Loss 28.836322784423828
# Epochs number 820
# Loss 28.81184959411621
# Epochs number 821
# Loss 28.787490844726562
# Epochs number 822
# Loss 28.763158798217773
# Epochs number 823
# Loss 28.738927841186523
# Epochs number 824
# Loss 28.714731216430664
# Epochs number 825
# Loss 28.69061279296875
# Epochs number 826
# Loss 28.66653823852539
# Epochs number 827
# Loss 28.642553329467773
# Epochs number 828
# Loss 28.618637084960938
# Epochs number 829
# Loss 28.594776153564453
# Epochs number 830
# Loss 28.570953369140625
# Epochs number 831
# Loss 28.547250747680664
# Epochs number 832
# Loss 28.523544311523438
# Epochs number 833
# Loss 28.49995994567871
# Epochs number 834
# Loss 28.476390838623047
# Epochs number 835
# Loss 28.45291519165039
# Epochs number 836
# Loss 28.429515838623047
# Epochs number 837
# Loss 28.4061336517334
# Epochs number 838
# Loss 28.38285255432129
# Epochs number 839
# Loss 28.359609603881836
# Epochs number 840
# Loss 28.336435317993164
# Epochs number 841
# Loss 28.313350677490234
# Epochs number 842
# Loss 28.290298461914062
# Epochs number 843
# Loss 28.267292022705078
# Epochs number 844
# Loss 28.24436378479004
# Epochs number 845
# Loss 28.221506118774414
# Epochs number 846
# Loss 28.198699951171875
# Epochs number 847
# Loss 28.175975799560547
# Epochs number 848
# Loss 28.153274536132812
# Epochs number 849
# Loss 28.130666732788086
# Epochs number 850
# Loss 28.108104705810547
# Epochs number 851
# Loss 28.085601806640625
# Epochs number 852
# Loss 28.06317710876465
# Epochs number 853
# Loss 28.040771484375
# Epochs number 854
# Loss 28.018468856811523
# Epochs number 855
# Loss 27.996185302734375
# Epochs number 856
# Loss 27.9740047454834
# Epochs number 857
# Loss 27.95184898376465
# Epochs number 858
# Loss 27.929767608642578
# Epochs number 859
# Loss 27.907724380493164
# Epochs number 860
# Loss 27.885761260986328
# Epochs number 861
# Loss 27.863845825195312
# Epochs number 862
# Loss 27.841999053955078
# Epochs number 863
# Loss 27.820175170898438
# Epochs number 864
# Loss 27.798486709594727
# Epochs number 865
# Loss 27.776752471923828
# Epochs number 866
# Loss 27.755157470703125
# Epochs number 867
# Loss 27.733570098876953
# Epochs number 868
# Loss 27.712078094482422
# Epochs number 869
# Loss 27.69061279296875
# Epochs number 870
# Loss 27.669225692749023
# Epochs number 871
# Loss 27.647897720336914
# Epochs number 872
# Loss 27.626602172851562
# Epochs number 873
# Loss 27.605365753173828
# Epochs number 874
# Loss 27.58420753479004
# Epochs number 875
# Loss 27.563064575195312
# Epochs number 876
# Loss 27.542001724243164
# Epochs number 877
# Loss 27.521015167236328
# Epochs number 878
# Loss 27.50008773803711
# Epochs number 879
# Loss 27.479162216186523
# Epochs number 880
# Loss 27.45833969116211
# Epochs number 881
# Loss 27.437549591064453
# Epochs number 882
# Loss 27.41678810119629
# Epochs number 883
# Loss 27.396148681640625
# Epochs number 884
# Loss 27.375503540039062
# Epochs number 885
# Loss 27.35495948791504
# Epochs number 886
# Loss 27.334436416625977
# Epochs number 887
# Loss 27.313961029052734
# Epochs number 888
# Loss 27.29355239868164
# Epochs number 889
# Loss 27.2731876373291
# Epochs number 890
# Loss 27.25288963317871
# Epochs number 891
# Loss 27.232650756835938
# Epochs number 892
# Loss 27.21245765686035
# Epochs number 893
# Loss 27.192310333251953
# Epochs number 894
# Loss 27.172183990478516
# Epochs number 895
# Loss 27.152196884155273
# Epochs number 896
# Loss 27.1321964263916
# Epochs number 897
# Loss 27.11227035522461
# Epochs number 898
# Loss 27.092370986938477
# Epochs number 899
# Loss 27.07257080078125
# Epochs number 900
# Loss 27.052743911743164
# Epochs number 901
# Loss 27.033039093017578
# Epochs number 902
# Loss 27.013378143310547
# Epochs number 903
# Loss 26.9937686920166
# Epochs number 904
# Loss 26.974151611328125
# Epochs number 905
# Loss 26.954647064208984
# Epochs number 906
# Loss 26.935161590576172
# Epochs number 907
# Loss 26.915771484375
# Epochs number 908
# Loss 26.896377563476562
# Epochs number 909
# Loss 26.8770751953125
# Epochs number 910
# Loss 26.857797622680664
# Epochs number 911
# Loss 26.838611602783203
# Epochs number 912
# Loss 26.819421768188477
# Epochs number 913
# Loss 26.80031967163086
# Epochs number 914
# Loss 26.781240463256836
# Epochs number 915
# Loss 26.762191772460938
# Epochs number 916
# Loss 26.743236541748047
# Epochs number 917
# Loss 26.724319458007812
# Epochs number 918
# Loss 26.705455780029297
# Epochs number 919
# Loss 26.68661117553711
# Epochs number 920
# Loss 26.6678524017334
# Epochs number 921
# Loss 26.64911460876465
# Epochs number 922
# Loss 26.630441665649414
# Epochs number 923
# Loss 26.611801147460938
# Epochs number 924
# Loss 26.59323501586914
# Epochs number 925
# Loss 26.57468032836914
# Epochs number 926
# Loss 26.556209564208984
# Epochs number 927
# Loss 26.537765502929688
# Epochs number 928
# Loss 26.519390106201172
# Epochs number 929
# Loss 26.501028060913086
# Epochs number 930
# Loss 26.482742309570312
# Epochs number 931
# Loss 26.4644718170166
# Epochs number 932
# Loss 26.446298599243164
# Epochs number 933
# Loss 26.428146362304688
# Epochs number 934
# Loss 26.410043716430664
# Epochs number 935
# Loss 26.391963958740234
# Epochs number 936
# Loss 26.37396812438965
# Epochs number 937
# Loss 26.356006622314453
# Epochs number 938
# Loss 26.33807373046875
# Epochs number 939
# Loss 26.320201873779297
# Epochs number 940
# Loss 26.302383422851562
# Epochs number 941
# Loss 26.284582138061523
# Epochs number 942
# Loss 26.266849517822266
# Epochs number 943
# Loss 26.249160766601562
# Epochs number 944
# Loss 26.23153305053711
# Epochs number 945
# Loss 26.21392822265625
# Epochs number 946
# Loss 26.196359634399414
# Epochs number 947
# Loss 26.178863525390625
# Epochs number 948
# Loss 26.161373138427734
# Epochs number 949
# Loss 26.143972396850586
# Epochs number 950
# Loss 26.126598358154297
# Epochs number 951
# Loss 26.109277725219727
# Epochs number 952
# Loss 26.091964721679688
# Epochs number 953
# Loss 26.074756622314453
# Epochs number 954
# Loss 26.057552337646484
# Epochs number 955
# Loss 26.040401458740234
# Epochs number 956
# Loss 26.023258209228516
# Epochs number 957
# Loss 26.006229400634766
# Epochs number 958
# Loss 25.989187240600586
# Epochs number 959
# Loss 25.972232818603516
# Epochs number 960
# Loss 25.95529556274414
# Epochs number 961
# Loss 25.938404083251953
# Epochs number 962
# Loss 25.92154884338379
# Epochs number 963
# Loss 25.904743194580078
# Epochs number 964
# Loss 25.887964248657227
# Epochs number 965
# Loss 25.871265411376953
# Epochs number 966
# Loss 25.85457420349121
# Epochs number 967
# Loss 25.83795166015625
# Epochs number 968
# Loss 25.821369171142578
# Epochs number 969
# Loss 25.8048095703125
# Epochs number 970
# Loss 25.78830337524414
# Epochs number 971
# Loss 25.7718448638916
# Epochs number 972
# Loss 25.755422592163086
# Epochs number 973
# Loss 25.739059448242188
# Epochs number 974
# Loss 25.722702026367188
# Epochs number 975
# Loss 25.7064208984375
# Epochs number 976
# Loss 25.690176010131836
# Epochs number 977
# Loss 25.6739501953125
# Epochs number 978
# Loss 25.657787322998047
# Epochs number 979
# Loss 25.64163589477539
# Epochs number 980
# Loss 25.625568389892578
# Epochs number 981
# Loss 25.609500885009766
# Epochs number 982
# Loss 25.59351348876953
# Epochs number 983
# Loss 25.57754135131836
# Epochs number 984
# Loss 25.56162452697754
# Epochs number 985
# Loss 25.54572868347168
# Epochs number 986
# Loss 25.529909133911133
# Epochs number 987
# Loss 25.514101028442383
# Epochs number 988
# Loss 25.49832534790039
# Epochs number 989
# Loss 25.48259735107422
# Epochs number 990
# Loss 25.466934204101562
# Epochs number 991
# Loss 25.4512939453125
# Epochs number 992
# Loss 25.43568992614746
# Epochs number 993
# Loss 25.420103073120117
# Epochs number 994
# Loss 25.404624938964844
# Epochs number 995
# Loss 25.389110565185547
# Epochs number 996
# Loss 25.373668670654297
# Epochs number 997
# Loss 25.3582706451416
# Epochs number 998
# Loss 25.342914581298828
# Epochs number 999
# Loss 25.32756996154785
# Epochs number 1000
# Loss 25.31229591369629
# Epochs number 1001
# Loss 25.29700469970703
# Epochs number 1002
# Loss 25.28183364868164
# Epochs number 1003
# Loss 25.266647338867188
# Epochs number 1004
# Loss 25.25152015686035
# Epochs number 1005
# Loss 25.236400604248047
# Epochs number 1006
# Loss 25.221378326416016
# Epochs number 1007
# Loss 25.206340789794922
# Epochs number 1008
# Loss 25.19137191772461
# Epochs number 1009
# Loss 25.176448822021484
# Epochs number 1010
# Loss 25.16150665283203
# Epochs number 1011
# Loss 25.14669418334961
# Epochs number 1012
# Loss 25.131832122802734
# Epochs number 1013
# Loss 25.117061614990234
# Epochs number 1014
# Loss 25.1022891998291
# Epochs number 1015
# Loss 25.08757781982422
# Epochs number 1016
# Loss 25.072893142700195
# Epochs number 1017
# Loss 25.05828285217285
# Epochs number 1018
# Loss 25.04364585876465
# Epochs number 1019
# Loss 25.029117584228516
# Epochs number 1020
# Loss 25.014577865600586
# Epochs number 1021
# Loss 25.00008773803711
# Epochs number 1022
# Loss 24.9856014251709
# Epochs number 1023
# Loss 24.971200942993164
# Epochs number 1024
# Loss 24.956819534301758
# Epochs number 1025
# Loss 24.94249153137207
# Epochs number 1026
# Loss 24.928142547607422
# Epochs number 1027
# Loss 24.913911819458008
# Epochs number 1028
# Loss 24.899669647216797
# Epochs number 1029
# Loss 24.88545799255371
# Epochs number 1030
# Loss 24.871295928955078
# Epochs number 1031
# Loss 24.857158660888672
# Epochs number 1032
# Loss 24.843069076538086
# Epochs number 1033
# Loss 24.82899284362793
# Epochs number 1034
# Loss 24.814987182617188
# Epochs number 1035
# Loss 24.800994873046875
# Epochs number 1036
# Loss 24.787057876586914
# Epochs number 1037
# Loss 24.773134231567383
# Epochs number 1038
# Loss 24.75925636291504
# Epochs number 1039
# Loss 24.745384216308594
# Epochs number 1040
# Loss 24.731609344482422
# Epochs number 1041
# Loss 24.71781349182129
# Epochs number 1042
# Loss 24.704069137573242
# Epochs number 1043
# Loss 24.690353393554688
# Epochs number 1044
# Loss 24.676685333251953
# Epochs number 1045
# Loss 24.663089752197266
# Epochs number 1046
# Loss 24.649477005004883
# Epochs number 1047
# Loss 24.635908126831055
# Epochs number 1048
# Loss 24.622356414794922
# Epochs number 1049
# Loss 24.608861923217773
# Epochs number 1050
# Loss 24.595413208007812
# Epochs number 1051
# Loss 24.581989288330078
# Epochs number 1052
# Loss 24.56856918334961
# Epochs number 1053
# Loss 24.555219650268555
# Epochs number 1054
# Loss 24.541887283325195
# Epochs number 1055
# Loss 24.52857780456543
# Epochs number 1056
# Loss 24.515321731567383
# Epochs number 1057
# Loss 24.502086639404297
# Epochs number 1058
# Loss 24.488893508911133
# Epochs number 1059
# Loss 24.475740432739258
# Epochs number 1060
# Loss 24.46261978149414
# Epochs number 1061
# Loss 24.449514389038086
# Epochs number 1062
# Loss 24.436450958251953
# Epochs number 1063
# Loss 24.42343521118164
# Epochs number 1064
# Loss 24.41042137145996
# Epochs number 1065
# Loss 24.3974552154541
# Epochs number 1066
# Loss 24.38454246520996
# Epochs number 1067
# Loss 24.371623992919922
# Epochs number 1068
# Loss 24.358753204345703
# Epochs number 1069
# Loss 24.34592056274414
# Epochs number 1070
# Loss 24.333133697509766
# Epochs number 1071
# Loss 24.320344924926758
# Epochs number 1072
# Loss 24.307613372802734
# Epochs number 1073
# Loss 24.294891357421875
# Epochs number 1074
# Loss 24.282251358032227
# Epochs number 1075
# Loss 24.269609451293945
# Epochs number 1076
# Loss 24.256988525390625
# Epochs number 1077
# Loss 24.244400024414062
# Epochs number 1078
# Loss 24.23186492919922
# Epochs number 1079
# Loss 24.219350814819336
# Epochs number 1080
# Loss 24.206880569458008
# Epochs number 1081
# Loss 24.194446563720703
# Epochs number 1082
# Loss 24.1820068359375
# Epochs number 1083
# Loss 24.169626235961914
# Epochs number 1084
# Loss 24.15726089477539
# Epochs number 1085
# Loss 24.14493179321289
# Epochs number 1086
# Loss 24.132627487182617
# Epochs number 1087
# Loss 24.120372772216797
# Epochs number 1088
# Loss 24.108110427856445
# Epochs number 1089
# Loss 24.095935821533203
# Epochs number 1090
# Loss 24.083751678466797
# Epochs number 1091
# Loss 24.07162857055664
# Epochs number 1092
# Loss 24.059532165527344
# Epochs number 1093
# Loss 24.04742431640625
# Epochs number 1094
# Loss 24.035383224487305
# Epochs number 1095
# Loss 24.023340225219727
# Epochs number 1096
# Loss 24.011394500732422
# Epochs number 1097
# Loss 23.9993953704834
# Epochs number 1098
# Loss 23.98750114440918
# Epochs number 1099
# Loss 23.975568771362305
# Epochs number 1100
# Loss 23.96371078491211
# Epochs number 1101
# Loss 23.95187759399414
# Epochs number 1102
# Loss 23.940067291259766
# Epochs number 1103
# Loss 23.928260803222656
# Epochs number 1104
# Loss 23.916528701782227
# Epochs number 1105
# Loss 23.90480613708496
# Epochs number 1106
# Loss 23.893123626708984
# Epochs number 1107
# Loss 23.881454467773438
# Epochs number 1108
# Loss 23.86981773376465
# Epochs number 1109
# Loss 23.858232498168945
# Epochs number 1110
# Loss 23.84665870666504
# Epochs number 1111
# Loss 23.835111618041992
# Epochs number 1112
# Loss 23.823585510253906
# Epochs number 1113
# Loss 23.812114715576172
# Epochs number 1114
# Loss 23.800636291503906
# Epochs number 1115
# Loss 23.789228439331055
# Epochs number 1116
# Loss 23.777799606323242
# Epochs number 1117
# Loss 23.76643180847168
# Epochs number 1118
# Loss 23.755084991455078
# Epochs number 1119
# Loss 23.743770599365234
# Epochs number 1120
# Loss 23.732471466064453
# Epochs number 1121
# Loss 23.721237182617188
# Epochs number 1122
# Loss 23.70998764038086
# Epochs number 1123
# Loss 23.69878578186035
# Epochs number 1124
# Loss 23.687631607055664
# Epochs number 1125
# Loss 23.676448822021484
# Epochs number 1126
# Loss 23.665355682373047
# Epochs number 1127
# Loss 23.654251098632812
# Epochs number 1128
# Loss 23.643205642700195
# Epochs number 1129
# Loss 23.632139205932617
# Epochs number 1130
# Loss 23.62115478515625
# Epochs number 1131
# Loss 23.610157012939453
# Epochs number 1132
# Loss 23.599224090576172
# Epochs number 1133
# Loss 23.588272094726562
# Epochs number 1134
# Loss 23.577417373657227
# Epochs number 1135
# Loss 23.566539764404297
# Epochs number 1136
# Loss 23.55569076538086
# Epochs number 1137
# Loss 23.544872283935547
# Epochs number 1138
# Loss 23.534074783325195
# Epochs number 1139
# Loss 23.523324966430664
# Epochs number 1140
# Loss 23.512584686279297
# Epochs number 1141
# Loss 23.50187110900879
# Epochs number 1142
# Loss 23.49118423461914
# Epochs number 1143
# Loss 23.48052406311035
# Epochs number 1144
# Loss 23.469898223876953
# Epochs number 1145
# Loss 23.459314346313477
# Epochs number 1146
# Loss 23.4487361907959
# Epochs number 1147
# Loss 23.438175201416016
# Epochs number 1148
# Loss 23.42765998840332
# Epochs number 1149
# Loss 23.417165756225586
# Epochs number 1150
# Loss 23.406692504882812
# Epochs number 1151
# Loss 23.396249771118164
# Epochs number 1152
# Loss 23.38585662841797
# Epochs number 1153
# Loss 23.375452041625977
# Epochs number 1154
# Loss 23.365083694458008
# Epochs number 1155
# Loss 23.354747772216797
# Epochs number 1156
# Loss 23.344430923461914
# Epochs number 1157
# Loss 23.334148406982422
# Epochs number 1158
# Loss 23.323888778686523
# Epochs number 1159
# Loss 23.313648223876953
# ...
# Loss 20.500308990478516
# Epochs number 1625
# Loss 20.497100830078125
# Epochs number 1626
# Loss 20.493900299072266
# Epochs number 1627
# Loss 20.490703582763672
# Epochs number 1628
# Loss 20.487531661987305
# Epochs number 1629
# Loss 20.484355926513672
# Epochs number 1630
# Loss 20.481182098388672
# Epochs number 1631
# Loss 20.47802734375
# Epochs number 1632
# Loss 20.474864959716797
# Epochs number 1633
# Loss 20.47171974182129
# Epochs number 1634
# Loss 20.46859359741211
# Epochs number 1635
# Loss 20.465463638305664
# Epochs number 1636
# Loss 20.46233558654785
# Epochs number 1637
# Loss 20.459239959716797
# Epochs number 1638
# Loss 20.45612144470215
# Epochs number 1639
# Loss 20.453014373779297
# Epochs number 1640
# Loss 20.449947357177734
# Epochs number 1641
# Loss 20.446849822998047
# Epochs number 1642
# Loss 20.443790435791016
# Epochs number 1643
# Loss 20.440715789794922
# Epochs number 1644
# Loss 20.437658309936523
# Epochs number 1645
# Loss 20.434621810913086
# Epochs number 1646
# Loss 20.43155860900879
# Epochs number 1647
# Loss 20.428529739379883
# Epochs number 1648
# Loss 20.425506591796875
# Epochs number 1649
# Loss 20.422460556030273
# Epochs number 1650
# Loss 20.41946792602539
# Epochs number 1651
# Loss 20.41644859313965
# Epochs number 1652
# Loss 20.413476943969727
# Epochs number 1653
# Loss 20.41047477722168
# Epochs number 1654
# Loss 20.407472610473633
# Epochs number 1655
# Loss 20.404521942138672
# Epochs number 1656
# Loss 20.401554107666016
# Epochs number 1657
# Loss 20.398576736450195
# Epochs number 1658
# Loss 20.3956241607666
# Epochs number 1659
# Loss 20.392667770385742
# Epochs number 1660
# Loss 20.389738082885742
# Epochs number 1661
# Loss 20.386816024780273
# Epochs number 1662
# Loss 20.383880615234375
# Epochs number 1663
# Loss 20.38096809387207
# Epochs number 1664
# Loss 20.378067016601562
# Epochs number 1665
# Loss 20.37514305114746
# Epochs number 1666
# Loss 20.372257232666016
# Epochs number 1667
# Loss 20.369359970092773
# Epochs number 1668
# Loss 20.366474151611328
# Epochs number 1669
# Loss 20.363601684570312
# Epochs number 1670
# Loss 20.360733032226562
# Epochs number 1671
# Loss 20.35788917541504
# Epochs number 1672
# Loss 20.355045318603516
# Epochs number 1673
# Loss 20.352191925048828
# Epochs number 1674
# Loss 20.349334716796875
# Epochs number 1675
# Loss 20.346508026123047
# Epochs number 1676
# Loss 20.343673706054688
# Epochs number 1677
# Loss 20.340871810913086
# Epochs number 1678
# Loss 20.33806037902832
# Epochs number 1679
# Loss 20.33523941040039
# Epochs number 1680
# Loss 20.332469940185547
# Epochs number 1681
# Loss 20.32966423034668
# Epochs number 1682
# Loss 20.326885223388672
# Epochs number 1683
# Loss 20.324121475219727
# Epochs number 1684
# Loss 20.321325302124023
# Epochs number 1685
# Loss 20.318578720092773
# Epochs number 1686
# Loss 20.315792083740234
# Epochs number 1687
# Loss 20.313064575195312
# Epochs number 1688
# Loss 20.310348510742188
# Epochs number 1689
# Loss 20.307598114013672
# Epochs number 1690
# Loss 20.30486488342285
# Epochs number 1691
# Loss 20.3021297454834
# Epochs number 1692
# Loss 20.299419403076172
# Epochs number 1693
# Loss 20.29673194885254
# Epochs number 1694
# Loss 20.29401206970215
# Epochs number 1695
# Loss 20.291324615478516
# Epochs number 1696
# Loss 20.288646697998047
# Epochs number 1697
# Loss 20.285934448242188
# Epochs number 1698
# Loss 20.283288955688477
# Epochs number 1699
# Loss 20.28060531616211
# Epochs number 1700
# Loss 20.2779541015625
# Epochs number 1701
# Loss 20.27529525756836
# Epochs number 1702
# Loss 20.272628784179688
# Epochs number 1703
# Loss 20.27001953125
# Epochs number 1704
# Loss 20.267370223999023
# Epochs number 1705
# Loss 20.26473045349121
# Epochs number 1706
# Loss 20.262113571166992
# Epochs number 1707
# Loss 20.25948715209961
# Epochs number 1708
# Loss 20.256874084472656
# Epochs number 1709
# Loss 20.254308700561523
# Epochs number 1710
# Loss 20.251678466796875
# Epochs number 1711
# Loss 20.24910545349121
# Epochs number 1712
# Loss 20.246532440185547
# Epochs number 1713
# Loss 20.24394416809082
# Epochs number 1714
# Loss 20.241376876831055
# Epochs number 1715
# Loss 20.238811492919922
# Epochs number 1716
# Loss 20.23625373840332
# Epochs number 1717
# Loss 20.233692169189453
# Epochs number 1718
# Loss 20.231142044067383
# Epochs number 1719
# Loss 20.22862434387207
# Epochs number 1720
# Loss 20.22609519958496
# Epochs number 1721
# Loss 20.223543167114258
# Epochs number 1722
# Loss 20.221044540405273
# Epochs number 1723
# Loss 20.218502044677734
# Epochs number 1724
# Loss 20.21600914001465
# Epochs number 1725
# Loss 20.21351432800293
# Epochs number 1726
# Loss 20.211008071899414
# Epochs number 1727
# Loss 20.208528518676758
# Epochs number 1728
# Loss 20.2060546875
# Epochs number 1729
# Loss 20.203556060791016
# Epochs number 1730
# Loss 20.20111083984375
# Epochs number 1731
# Loss 20.19864845275879
# Epochs number 1732
# Loss 20.19618797302246
# Epochs number 1733
# Loss 20.1937255859375
# Epochs number 1734
# Loss 20.191268920898438
# Epochs number 1735
# Loss 20.18885040283203
# Epochs number 1736
# Loss 20.18641471862793
# Epochs number 1737
# Loss 20.183979034423828
# Epochs number 1738
# Loss 20.181554794311523
# Epochs number 1739
# Loss 20.179126739501953
# Epochs number 1740
# Loss 20.17673110961914
# Epochs number 1741
# Loss 20.174333572387695
# Epochs number 1742
# Loss 20.171918869018555
# Epochs number 1743
# Loss 20.1695499420166
# Epochs number 1744
# Loss 20.167152404785156
# Epochs number 1745
# Loss 20.164775848388672
# Epochs number 1746
# Loss 20.162395477294922
# Epochs number 1747
# Loss 20.16001319885254
# Epochs number 1748
# Loss 20.157657623291016
# Epochs number 1749
# Loss 20.155324935913086
# Epochs number 1750
# Loss 20.152956008911133
# Epochs number 1751
# Loss 20.150619506835938
# Epochs number 1752
# Loss 20.148273468017578
# Epochs number 1753
# Loss 20.14593505859375
# Epochs number 1754
# Loss 20.143625259399414
# Epochs number 1755
# Loss 20.141300201416016
# Epochs number 1756
# Loss 20.138965606689453
# Epochs number 1757
# Loss 20.136667251586914
# Epochs number 1758
# Loss 20.134349822998047
# Epochs number 1759
# Loss 20.13205909729004
# Epochs number 1760
# Loss 20.12978744506836
# Epochs number 1761
# Loss 20.127483367919922
# Epochs number 1762
# Loss 20.12518882751465
# Epochs number 1763
# Loss 20.1229248046875
# Epochs number 1764
# Loss 20.120655059814453
# Epochs number 1765
# Loss 20.118396759033203
# Epochs number 1766
# Loss 20.116134643554688
# Epochs number 1767
# Loss 20.11387825012207
# Epochs number 1768
# Loss 20.111637115478516
# Epochs number 1769
# Loss 20.109394073486328
# Epochs number 1770
# Loss 20.10713768005371
# Epochs number 1771
# Loss 20.10491943359375
# Epochs number 1772
# Loss 20.102691650390625
# Epochs number 1773
# Loss 20.10049057006836
# Epochs number 1774
# Loss 20.098247528076172
# Epochs number 1775
# Loss 20.096046447753906
# Epochs number 1776
# Loss 20.093860626220703
# Epochs number 1777
# Loss 20.09164047241211
# Epochs number 1778
# Loss 20.089458465576172
# Epochs number 1779
# Loss 20.087270736694336
# Epochs number 1780
# Loss 20.0850830078125
# Epochs number 1781
# Loss 20.08289909362793
# Epochs number 1782
# Loss 20.080732345581055
# Epochs number 1783
# Loss 20.078569412231445
# Epochs number 1784
# Loss 20.076414108276367
# Epochs number 1785
# Loss 20.074247360229492
# Epochs number 1786
# Loss 20.07210350036621
# Epochs number 1787
# Loss 20.06996726989746
# Epochs number 1788
# Loss 20.067813873291016
# Epochs number 1789
# Loss 20.065692901611328
# Epochs number 1790
# Loss 20.063552856445312
# Epochs number 1791
# Loss 20.061439514160156
# Epochs number 1792
# Loss 20.059316635131836
# Epochs number 1793
# Loss 20.057193756103516
# Epochs number 1794
# Loss 20.055097579956055
# Epochs number 1795
# Loss 20.05300521850586
# Epochs number 1796
# Loss 20.050899505615234
# Epochs number 1797
# Loss 20.048816680908203
# Epochs number 1798
# Loss 20.04672622680664
# Epochs number 1799
# Loss 20.044639587402344
# Epochs number 1800
# Loss 20.042585372924805
# Epochs number 1801
# Loss 20.04049301147461
# Epochs number 1802
# Loss 20.03843879699707
# Epochs number 1803
# Loss 20.036359786987305
# Epochs number 1804
# Loss 20.03431510925293
# Epochs number 1805
# Loss 20.032272338867188
# Epochs number 1806
# Loss 20.030223846435547
# Epochs number 1807
# Loss 20.02815818786621
# Epochs number 1808
# Loss 20.026151657104492
# Epochs number 1809
# Loss 20.024105072021484
# Epochs number 1810
# Loss 20.022098541259766
# Epochs number 1811
# Loss 20.020065307617188
# Epochs number 1812
# Loss 20.018068313598633
# Epochs number 1813
# Loss 20.016033172607422
# Epochs number 1814
# Loss 20.014034271240234
# Epochs number 1815
# Loss 20.012039184570312
# Epochs number 1816
# Loss 20.01003074645996
# Epochs number 1817
# Loss 20.008052825927734
# Epochs number 1818
# Loss 20.006046295166016
# Epochs number 1819
# Loss 20.004074096679688
# Epochs number 1820
# Loss 20.00210952758789
# Epochs number 1821
# Loss 20.00013542175293
# Epochs number 1822
# Loss 19.998165130615234
# Epochs number 1823
# Loss 19.9962158203125
# Epochs number 1824
# Loss 19.994247436523438
# Epochs number 1825
# Loss 19.99228858947754
# Epochs number 1826
# Loss 19.990354537963867
# Epochs number 1827
# Loss 19.988418579101562
# Epochs number 1828
# Loss 19.986474990844727
# Epochs number 1829
# Loss 19.984546661376953
# Epochs number 1830
# Loss 19.98263168334961
# Epochs number 1831
# Loss 19.98069953918457
# Epochs number 1832
# Loss 19.978778839111328
# Epochs number 1833
# Loss 19.97686004638672
# Epochs number 1834
# Loss 19.97496223449707
# Epochs number 1835
# Loss 19.97306251525879
# Epochs number 1836
# Loss 19.971162796020508
# Epochs number 1837
# Loss 19.969261169433594
# Epochs number 1838
# Loss 19.96738052368164
# Epochs number 1839
# Loss 19.96547508239746
# Epochs number 1840
# Loss 19.963613510131836
# Epochs number 1841
# Loss 19.961740493774414
# Epochs number 1842
# Loss 19.959863662719727
# Epochs number 1843
# Loss 19.95800018310547
# Epochs number 1844
# Loss 19.956134796142578
# Epochs number 1845
# Loss 19.95430564880371
# Epochs number 1846
# Loss 19.95241355895996
# Epochs number 1847
# Loss 19.950580596923828
# Epochs number 1848
# Loss 19.948734283447266
# Epochs number 1849
# Loss 19.946884155273438
# Epochs number 1850
# Loss 19.945056915283203
# Epochs number 1851
# Loss 19.9432430267334
# Epochs number 1852
# Loss 19.9414119720459
# Epochs number 1853
# Loss 19.939594268798828
# Epochs number 1854
# Loss 19.937759399414062
# Epochs number 1855
# Loss 19.93596839904785
# Epochs number 1856
# Loss 19.93416404724121
# Epochs number 1857
# Loss 19.932353973388672
# Epochs number 1858
# Loss 19.930553436279297
# Epochs number 1859
# Loss 19.928775787353516
# Epochs number 1860
# Loss 19.92697525024414
# Epochs number 1861
# Loss 19.92519187927246
# Epochs number 1862
# Loss 19.92340660095215
# Epochs number 1863
# Loss 19.921611785888672
# Epochs number 1864
# Loss 19.919864654541016
# Epochs number 1865
# Loss 19.918102264404297
# Epochs number 1866
# Loss 19.91632843017578
# Epochs number 1867
# Loss 19.914567947387695
# Epochs number 1868
# Loss 19.912822723388672
# Epochs number 1869
# Loss 19.91106605529785
# Epochs number 1870
# Loss 19.909337997436523
# Epochs number 1871
# Loss 19.907573699951172
# Epochs number 1872
# Loss 19.90586280822754
# Epochs number 1873
# Loss 19.904138565063477
# Epochs number 1874
# Loss 19.902376174926758
# Epochs number 1875
# Loss 19.90066146850586
# Epochs number 1876
# Loss 19.89896011352539
# Epochs number 1877
# Loss 19.89722442626953
# Epochs number 1878
# Loss 19.895530700683594
# Epochs number 1879
# Loss 19.893823623657227
# Epochs number 1880
# Loss 19.892108917236328
# Epochs number 1881
# Loss 19.890424728393555
# Epochs number 1882
# Loss 19.88871192932129
# Epochs number 1883
# Loss 19.887033462524414
# Epochs number 1884
# Loss 19.8853702545166
# Epochs number 1885
# Loss 19.883668899536133
# Epochs number 1886
# Loss 19.881999969482422
# Epochs number 1887
# Loss 19.88033103942871
# Epochs number 1888
# Loss 19.878643035888672
# Epochs number 1889
# Loss 19.876976013183594
# Epochs number 1890
# Loss 19.875324249267578
# Epochs number 1891
# Loss 19.87367057800293
# Epochs number 1892
# Loss 19.872020721435547
# Epochs number 1893
# Loss 19.870361328125
# Epochs number 1894
# Loss 19.86871910095215
# Epochs number 1895
# Loss 19.867097854614258
# Epochs number 1896
# Loss 19.865455627441406
# Epochs number 1897
# Loss 19.86380958557129
# Epochs number 1898
# Loss 19.86219596862793
# Epochs number 1899
# Loss 19.860570907592773
# Epochs number 1900
# Loss 19.858957290649414
# Epochs number 1901
# Loss 19.85733413696289
# Epochs number 1902
# Loss 19.855724334716797
# Epochs number 1903
# Loss 19.854110717773438
# Epochs number 1904
# Loss 19.852521896362305
# Epochs number 1905
# Loss 19.850908279418945
# Epochs number 1906
# Loss 19.849319458007812
# Epochs number 1907
# Loss 19.847721099853516
# Epochs number 1908
# Loss 19.84613037109375
# Epochs number 1909
# Loss 19.84456443786621
# Epochs number 1910
# Loss 19.842958450317383
# Epochs number 1911
# Loss 19.84140396118164
# Epochs number 1912
# Loss 19.839815139770508
# Epochs number 1913
# Loss 19.838245391845703
# Epochs number 1914
# Loss 19.83668327331543
# Epochs number 1915
# Loss 19.835140228271484
# Epochs number 1916
# Loss 19.833555221557617
# Epochs number 1917
# Loss 19.832035064697266
# Epochs number 1918
# Loss 19.830467224121094
# Epochs number 1919
# Loss 19.828922271728516
# Epochs number 1920
# Loss 19.8273868560791
# Epochs number 1921
# Loss 19.82583236694336
# Epochs number 1922
# Loss 19.824291229248047
# Epochs number 1923
# Loss 19.822782516479492
# Epochs number 1924
# Loss 19.821247100830078
# Epochs number 1925
# Loss 19.819726943969727
# Epochs number 1926
# Loss 19.818225860595703
# Epochs number 1927
# Loss 19.81668472290039
# Epochs number 1928
# Loss 19.815195083618164
# Epochs number 1929
# Loss 19.813684463500977
# Epochs number 1930
# Loss 19.812183380126953
# Epochs number 1931
# Loss 19.810678482055664
# Epochs number 1932
# Loss 19.809188842773438
# Epochs number 1933
# Loss 19.807689666748047
# Epochs number 1934
# Loss 19.806209564208984
# Epochs number 1935
# Loss 19.80471420288086
# Epochs number 1936
# Loss 19.803258895874023
# Epochs number 1937
# Loss 19.801776885986328
# Epochs number 1938
# Loss 19.800273895263672
# Epochs number 1939
# Loss 19.798812866210938
# Epochs number 1940
# Loss 19.797359466552734
# Epochs number 1941
# Loss 19.79587745666504
# Epochs number 1942
# Loss 19.794422149658203
# Epochs number 1943
# Loss 19.7929744720459
# Epochs number 1944
# Loss 19.79151725769043
# Epochs number 1945
# Loss 19.790075302124023
# Epochs number 1946
# Loss 19.788616180419922
# Epochs number 1947
# Loss 19.787185668945312
# Epochs number 1948
# Loss 19.785747528076172
# Epochs number 1949
# Loss 19.784305572509766
# Epochs number 1950
# Loss 19.78287696838379
# Epochs number 1951
# Loss 19.781469345092773
# Epochs number 1952
# Loss 19.780019760131836
# Epochs number 1953
# Loss 19.778627395629883
# Epochs number 1954
# Loss 19.777177810668945
# Epochs number 1955
# Loss 19.775787353515625
# Epochs number 1956
# Loss 19.774364471435547
# Epochs number 1957
# Loss 19.772981643676758
# Epochs number 1958
# Loss 19.771560668945312
# Epochs number 1959
# Loss 19.77017593383789
# Epochs number 1960
# Loss 19.76877784729004
# Epochs number 1961
# Loss 19.767353057861328
# Epochs number 1962
# Loss 19.766002655029297
# Epochs number 1963
# Loss 19.764604568481445
# Epochs number 1964
# Loss 19.763200759887695
# Epochs number 1965
# Loss 19.761850357055664
# Epochs number 1966
# Loss 19.760467529296875
# Epochs number 1967
# Loss 19.759113311767578
# Epochs number 1968
# Loss 19.757741928100586
# Epochs number 1969
# Loss 19.756370544433594
# Epochs number 1970
# Loss 19.754985809326172
# Epochs number 1971
# Loss 19.753644943237305
# Epochs number 1972
# Loss 19.75228500366211
# Epochs number 1973
# Loss 19.75092124938965
# Epochs number 1974
# Loss 19.74959373474121
# Epochs number 1975
# Loss 19.748260498046875
# Epochs number 1976
# Loss 19.746910095214844
# Epochs number 1977
# Loss 19.745555877685547
# Epochs number 1978
# Loss 19.744220733642578
# Epochs number 1979
# Loss 19.74289894104004
# Epochs number 1980
# Loss 19.741573333740234
# Epochs number 1981
# Loss 19.7402400970459
# Epochs number 1982
# Loss 19.738922119140625
# Epochs number 1983
# Loss 19.737611770629883
# Epochs number 1984
# Loss 19.736278533935547
# Epochs number 1985
# Loss 19.734981536865234
# Epochs number 1986
# Loss 19.733688354492188
# Epochs number 1987
# Loss 19.732372283935547
# Epochs number 1988
# Loss 19.73105812072754
# Epochs number 1989
# Loss 19.729778289794922
# Epochs number 1990
# Loss 19.728466033935547
# Epochs number 1991
# Loss 19.7271728515625
# Epochs number 1992
# Loss 19.725906372070312
# Epochs number 1993
# Loss 19.724613189697266
# Epochs number 1994
# Loss 19.723318099975586
# Epochs number 1995
# Loss 19.7220458984375
# Epochs number 1996
# Loss 19.72076416015625
# Epochs number 1997
# Loss 19.719493865966797
# Epochs number 1998
# Loss 19.71823501586914
# Epochs number 1999
# Loss 19.716962814331055

# %%
print('Predictions')
print(predictions)

print('Targets')
print(target_tensor)
# Out:
# Predictions
# tensor([[ 72.3719,  47.2880],
#         [108.8605,  69.4659],
#         [169.5136,  83.7633],
#         [ 44.3203,  45.7111],
#         [125.5783,  52.9186]], grad_fn=<AddBackward0>)
# Targets
# tensor([[ 58.,  77.],
#         [ 78., 100.],
#         [122., 130.],
#         [ 25.,  35.],
#         [113., 120.]])
